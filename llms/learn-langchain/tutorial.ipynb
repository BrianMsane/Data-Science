# %%
import yaml

from langchain_openai import ChatOpenAI
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
with open('params.yml', 'r') as f:
    params = yaml.safe_load(f)

# %%
llm = ChatOpenAI(
    model=params['model']
)
